# %% [markdown]
# <h3>Importing all the required libraries</h3>

# %%
from tweepy import OAuthHandler
from tweepy import API
from tweepy import Cursor
from datetime import datetime, date, time , timedelta
from collections import Counter
import sys

# %% [markdown]
# <h3>Twitter API Authentication Variables</h3>
# <h5>Enter your own consumer_key, consumer_secret, access_token and access_token_secret by replacing the stars ("*******")

# %%
consumer_key="******************************"
consumer_secret="**********************************"
access_token="*******************************"
access_token_secret="**********************************"

# %% [markdown]
# <h3>Authorization and initialization</h3>
# <h6>It only allows access to a users most recent 3240 tweets</h6>
# <p>1. Authorization to consumer key and consumer secret<br>
# 2. Access to user's access key and access secret
# <br>
# 3. Calling API</p>

# %%
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
auth_api = API(auth)

# %% [markdown]
# <h3>Specifying user's id

# %%
item = auth_api.get_user('midasIIITD')

# %% [markdown]
# <h6>item.created_at holds the creation date of the account anditem.statuses_count will calculate the average Tweets per day rate of that account

# %%
tweet = item.created_at 
tweets = item.statuses_count
# Out:
# datetime.datetime(2018, 7, 23, 11, 26, 4)

# %% [markdown]
# <h3>WORK</h3>
# <h6>Cursor allows us to stream data from the query without having to manually query for data.<br><br>
#     Collected dlists of all hastags and mentions seen in tweets.

# %%
hashtags = []
mentions = []
tweet_count = 0
end_date = datetime.utcnow()- timedelta(days=30)

for status in Cursor(auth_api.user_timeline, id = 'midasIIITD').items():
    tweet_count += 1
    if hasattr(status, "entities"):
        entities = status.entities
        if "hashtags" in entities:
            for ent in entities["hashtags"]:
                if ent is not None:
                    if "text" in ent:
                        hashtag = ent["text"]
                        if hashtag is not None:
                            hashtags.append(hashtag)
        if "user_mentions" in entities:
            for ent in entities["user_mentions"]:
                if ent is not None:
                    if "screen_name" in ent:
                        name = ent["screen_name"]
                        if name is not None:
                            mentions.append(name)
        if status.created_at < end_date:
            break

# %%
print(hashtags)
print(mentions)
# Out:
# ['Free', 'Books', 'DeepLearning', 'KDN', 'PortfolioCreationinDesign', 'Kaggle', 'DeepLearning']
# ...

# %% [markdown]
# <h2>Get tweets </h2>
# <h6>Making initial request for most recent tweets

# %%
tweets = auth_api.user_timeline(screen_name='midasIIITD')
tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x000001344DFCFD68>, _json={'created_at': 'Mon Apr 08 07:08:12 +0000 2019', 'id': 1115149324533542912, 'id_str': '1115149324533542912', 'text': 'Many Congratulations to @midasIIITD student, Shagun Uppal @shagunuppls, on getting selected for the summer internsh… https://t.co/bzhiSm4zuB', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'midasIIITD', 'name': 'MIDAS IIITD', 'id': 1021355762575073281, 'id_str': '1021355762575073281', 'indices': [24, 35]}, {'screen_name': 'shagunuppls', 'name': 'shagun uppal', 'id': 1399417358, 'id_str': '1399417358', 'indices': [58, 70]}], 'urls': [{'url': 'https://t.co/bzhiSm4zuB', 'expanded_url': 'https://twitter.com/i/web/status/1115149324533542912', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, '
# ...

# %% [markdown]
# <h3>Collecting all the required attributes

# %%
for tweet in tweets:
    count = 0 
    print(tweet.text)
    print("TIME:::::,",tweet.created_at)
    print("RETWEET COUNT:::,", tweet.retweet_count)
    print("FAVOURITE COUNT::",tweet.favorite_count)
    media = tweet.entities.get('media', [])
    for med in media:
        count += 1
    print("COUNT OF IMAGES ", count)
# Out:
# Many Congratulations to @midasIIITD student, Shagun Uppal @shagunuppls, on getting selected for the summer internsh… https://t.co/bzhiSm4zuB
# TIME:::::, 2019-04-08 07:08:12
# RETWEET COUNT:::, 1
# FAVOURITE COUNT:: 6
# COUNT OF IMAGES  0
# @midasIIITD thanks all students who have appeared for the interview yesterday. We will announce the interview resul… https://t.co/qxESgZPtKJ
# TIME:::::, 2019-04-08 03:27:42
# RETWEET COUNT:::, 0
# FAVOURITE COUNT:: 3
# COUNT OF IMAGES  0
# @himanchalchandr Meanwhile, complete CV/NLP task first.
# TIME:::::, 2019-04-07 14:17:29
# RETWEET COUNT:::, 0
# FAVOURITE COUNT:: 0
# COUNT OF IMAGES  0
# @sayangdipto123 Submit as per the guideline again.
# TIME:::::, 2019-04-07 14:17:09
# RETWEET COUNT:::, 0
# FAVOURITE COUNT:: 0
# COUNT OF IMAGES  0
# We request all students whose interview are scheduled today to join at the time given to them and not before or aft… https://t.co/7cnrlj1b9Q
# TIME:::::, 2019-04-07 11:43:24
# RETWEET COUNT:::, 1
# ...
